# %%
import litminion as lm

# %%
lm.set_email("rebecca.sessa@studio.unibo.it")

# %%
#search pubmed

ids = lm.search_pubmed(
    query="JAK inhibitor",
    max_results=10,
)

print(ids)
print(len(ids))
# Out:
# ['42365190', '42364375', '42364256', '42364020', '42362915', '42362624', '42361097', '42360790', '42358656', '42356447']
# 10

# %%
#fetch articles

records = lm.fetch_pubmed(ids)

print(type(records))
print(len(records))
print(type(records[0]))
print(records[0].keys())
# Out:
# <class 'list'>
# 10
# <class 'Bio.Entrez.Parser.DictionaryElement'>
# dict_keys(['MedlineCitation', 'PubmedData'])
