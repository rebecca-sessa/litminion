# %%
import litminion as lm
import pandas as pd

# %%
lm.set_email("rebecca.sessa@studio.unibo.it")

df = lm.download_pubmed(
    query="JAK inhibitor",
    max_results=10,
)

df.head()
# Out:
#        PMID                                              Title  \
# 0  42364256  Ocular sarcoidosis: from clinical signs to tar...
# 1  42362915  Clinical and prognostic significance of concom...
# 2  42362624  Differential functional and lipidomic impact o...
# 3  42361097  Advanced therapies in management of pediatric ...
# 4  42360790  Detectable safety gestalt of rheumatoid arthri...
#
#                                             Abstract  \
# 0  Ocular sarcoidosis is a frequent manifestation...
# 1  There is growing interest in the association b...
# 2  High-density lipoprotein (HDL) presents athero...
# 3  Pediatric inflammatory bowel disease (PIBD) ha...
# 4  To provide a meta-level comparison of standard...
#
#                           Journal  Year  \
# 0   Current opinion in immunology  2026
# 1            Annals of hematology  2026
# 2              Scientific reports  2026
# 3   Current opinion in pediatrics  2026
# 4  Rheumatology (Oxford, England)  2026
#
# ...
