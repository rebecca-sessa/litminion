# %%
import litminion as lm

# %%
lm.set_email("rebecca.sessa@studio.unibo.it")

# %%
#download corpus

df = lm.download_pubmed(
    query="JAK inhibitor",
    max_results=10,
)

df.head()
# Out:
#        PMID                                              Title  \
# 0  42365190  Comment on: The use of Janus kinase inhibitors...
# 1  42364375  Efficacy and safety of JAK inhibitors in Behçe...
# 2  42364256  Ocular sarcoidosis: from clinical signs to tar...
# 3  42364020  Filgotinib induces apoptosis in colorectal can...
# 4  42362915  Clinical and prognostic significance of concom...
#
#                                             Abstract  \
# 0
# 1  Given the active role of the JAK signaling pat...
# 2  Ocular sarcoidosis is a frequent manifestation...
# 3  Colorectal cancer remains a significant health...
# 4  There is growing interest in the association b...
#
#                                 Journal  Year  \
# 0                 Eye (London, England)  2026
# 1  Seminars in arthritis and rheumatism  2026
# 2         Current opinion in immunology  2026
# 3             Molecular biology reports  2026
# 4                  Annals of hematology  2026
#
#                                              Authors          PublicationType
# 0  Natasa Vidovic Valentincic; Matija Tomsic; Pol...                   Letter
# 1  Bercemhan Sulu; Sinem Nihal Esatoglu; Gozde Ku...          Journal Article
# 2  Thomas El Jammal; Robin Jacquot; Stéphane Abra...  Journal Article; Review
# 3  Ying Zhou; Zhen Li; Yanyang Zhao; Chenmeng Li;...          Journal Article
# 4  Alessandro Costa; Olga Mulas; Marianna Greco; ...          Journal Article

# %%
#dataset info

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PMID             10 non-null     str
#  1   Title            10 non-null     str
#  2   Abstract         10 non-null     str
#  3   Journal          10 non-null     str
#  4   Year             10 non-null     str
#  5   Authors          10 non-null     str
#  6   PublicationType  10 non-null     str
# dtypes: str(7)
# memory usage: 692.0 bytes

# %%
#missing values

df.isna().sum()
# Out:
# PMID               0
# Title              0
# Abstract           0
# Journal            0
# Year               0
# Authors            0
# PublicationType    0
# dtype: int64

# %%
#publication types
df["PublicationType"].value_counts()
# Out:
# PublicationType
# Journal Article            8
# Letter                     1
# Journal Article; Review    1
# Name: count, dtype: int64

# %%
df[df["Abstract"] == ""]
# Out:
#        PMID                                              Title Abstract  \
# 0  42365190  Comment on: The use of Janus kinase inhibitors...
#
#                  Journal  Year  \
# 0  Eye (London, England)  2026
#
#                                              Authors PublicationType
# 0  Natasa Vidovic Valentincic; Matija Tomsic; Pol...          Letter
